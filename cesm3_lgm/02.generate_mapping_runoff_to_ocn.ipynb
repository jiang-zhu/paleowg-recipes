# %% [markdown]
# ---
# # Create runoff to ocean mapping files for CESM3 LGM
# - You could also run this in shell environment
# - Be sure to use enough memory (I used 40 GB on Casper)
# - This step depends on the LGM SCRIP file from 01.setup_mom6_bathy.ipynb
# - Tools used
#   - [runoff_to_ocn](https://github.com/ESMCI/cime/blob/5eff840b3eb6243b97d65a1989cedc5ebcbcd3c7/tools/mapping/gen_mapping_files/runoff_to_ocn/README)

# %%
import subprocess
import datetime

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ---
# # Input files and settings for generating mapping files

# %%
ocn_SCRIP = '/glade/campaign/cgd/ppc/jiangzhu/setup_data/mom_topo/tx2_3v2_SCRIP_230415_21ka_240518.nc'

mapping_files = {}

mapping_files['r2o_liq'] = {
    'src_gridname': 'r05',
    'src_gridtype': 'rtm',
    'src_grid': '/glade/campaign/cesm/cesmdata/inputdata/lnd/clm2/rtmdata/rdirc.05.061026',
    'eFold': 250000.0,
    'rMax': 250000.0,
}

mapping_files['r2o_ice'] = {
    'src_gridname': 'r05',
    'src_gridtype': 'rtm',
    'src_grid': '/glade/campaign/cesm/cesmdata/inputdata/lnd/clm2/rtmdata/rdirc.05.061026',
    'eFold': 1000000.0,
    'rMax': 1000000.0,
}

# %% [markdown]
# ---
# # Output directory (output file names will be derived automatically)

# %%
today = datetime.date.today().strftime("%Y%m%d")
print(today)

work_dir = '/glade/campaign/cgd/ppc/jiangzhu/setup_data/mapping'
# Out:
# 20250127

# %% [markdown]
# ---
# # Tool used

# %%
runoff_map_exe = '/glade/campaign/cesm/development/palwg/scripts/setup/runoff_to_ocn/runoff_map'

# %% [markdown]
# ---
# # River mapping with multiple settings in eFold & rMax

# %%
# %%time

for key in mapping_files.keys():
    print(key)

    src_gridname = mapping_files[key]['src_gridname']
    src_gridtype = mapping_files[key]['src_gridtype']
    src_grid = mapping_files[key]['src_grid']
    eFold = mapping_files[key]['eFold']
    rMax = mapping_files[key]['rMax']

    eFold_km = f"{eFold/1e3:.0f}"
    rMax_km = f"{rMax/1e3:.0f}"

    file_nn     = f'{work_dir}/map_{src_gridname}_to_tx2_3v2_21ka_nn_e{eFold_km}r{rMax_km}_{today}.nc'
    file_smooth = f'{work_dir}/map_{src_gridname}_to_tx2_3v2_21ka_sm_e{eFold_km}r{rMax_km}_{today}.nc'
    file_new    = f'{work_dir}/map_{src_gridname}_to_tx2_3v2_21ka_nnsm_e{eFold_km}r{rMax_km}_{today}.nc'

    with open(f"{work_dir}/map_{src_gridname}_to_tx2_3v2_21ka_e{eFold_km}r{rMax_km}.nml", "w") as f:

        f.write('&input_nml\n')
        f.write(f"gridtype     = '{src_gridtype}'\n")
        f.write(f"file_roff    = '{src_grid}'\n")
        f.write(f"file_ocn     = '{ocn_SCRIP}'\n")
        f.write(f"file_nn      = '{file_nn}'\n")
        f.write(f"file_smooth  = '{file_smooth}'\n")
        f.write(f"file_new     = '{file_new}'\n")
        f.write(f"title        = 'runoff map: {src_gridname} -> tx2_3v2 21ka, nearest neighbor and smoothed'\n")
        f.write(f"eFold        = {eFold}\n")
        f.write(f"rMax         = {rMax}\n")
        f.write(f"step1        = .true.\n")
        f.write(f"step2        = .true.\n")
        f.write(f"step3        = .true.\n")
        f.write(f"/\n")

    cmd = f"{runoff_map_exe} < {work_dir}/map_{src_gridname}_to_tx2_3v2_21ka_e{eFold_km}r{rMax_km}.nml"  
    print(cmd)
    subprocess.run(cmd, shell=True)
# Out:
# r2o_liq
# /glade/campaign/cesm/development/palwg/scripts/setup/runoff_to_ocn/runoff_map < /glade/campaign/cgd/ppc/jiangzhu/setup_data/mapping/map_r05_to_tx2_3v2_21ka_e250r250.nml
# (main) -------------------------------------------------------------------------
# (main) correct/smooth/sort runoff -> ocean map
# (main) -------------------------------------------------------------------------
# (main) -------------------------------------------------------------------------
# (main) Step 0:  read input namelist data
# (main) -------------------------------------------------------------------------
# (main) Namelist values...
# (main)    gridtype                       = rtm
# (main)    file_roff                      = /glade/campaign/cesm/cesmdata/inputdata/lnd/clm2/rtmdata/rdirc.05.061026
# (main)    file_ocn (global)              = /glade/campaign/cgd/ppc/jiangzhu/setup_data/mom_topo/tx2_3v2_SCRIP_230415_21ka_240518.nc
# (main)    file_ocn (coast)               = /glade/campaign/cgd/ppc/jiangzhu/setup_data/mom_topo/tx2_3v2_SCRIP_230415_21ka_240518.nc
# (main)    file_nn                        = /glade/campaign/cgd/ppc/jiangzhu/setup_data/mapping/map_r05_to_tx2_3v2_21ka_nn_e250r250_20250127.nc
# (main)    file_smooth                    = /glade/campaign/cgd/ppc/jiangzhu/setup_data/mapping/map_r05_to_tx2_3v2_21ka_sm_e250r250_20250127.nc
# (main)    file_new                       = /glade/campaign/cgd/ppc/jiangzhu/setup_data/mapping/map_r05_to_tx2_3v2_21ka_nnsm_e250r250_20250127.nc
# (main)    title                          = runoff map: r05 -> tx2_3v2 21ka, nearest neighbor and smoothed
# (main)    eFold distance                 =  2.500000E+05
# (main)    rMax  distance                 =  2.500000E+05
# (main)    restrict_smooth_src_to_nn_dest = T
# (main)    step1                          = T
# (main)    step2                          = T
# (main)    step3                          = T
# (main) date & time: 2025-01-27  10:37:34
# (main) -------------------------------------------------------------------------
# (main) Step 1: read grid info & create nearest neighbor map
# (main) -------------------------------------------------------------------------
# (map_gridRead) read source domain info -- hardwired for 1/2 degree clm/rtm rdirc ascii file
# (map_gridRead) read destination domain info -- pop grid
# (map_DestGridRead) ocn data file = /glade/campaign/cgd/ppc/jiangzhu/setup_data/mom_topo/tx2_3v2_SCRIP_230415_21ka_240518.nc
# (map_gridRead) derive info required to compute NN map
# (map_gridRead) fill in missing boxes and
# (map_gridRead) make sure there are at least vcells_req valid cells per bin
#  (map_gridRead)  fill pass number           1  count =        54300
#  (map_gridRead)  fill pass number           2  count =        24118
#  (map_gridRead)  fill pass number           3  count =        21068
#  (map_gridRead)  fill pass number           4  count =        18486
#  (map_gridRead)  fill pass number           5  count =        16186
#  (map_gridRead)  fill pass number           6  count =        14023
#  (map_gridRead)  fill pass number           7  count =        12096
#  (map_gridRead)  fill pass number           8  count =        10343
#  (map_gridRead)  fill pass number           9  count =         8728
#  (map_gridRead)  fill pass number          10  count =         7326
#  (map_gridRead)  fill pass number          11  count =         6082
#  (map_gridRead)  fill pass number          12  count =         4919
#  (map_gridRead)  fill pass number          13  count =         3874
#  (map_gridRead)  fill pass number          14  count =         2957
#  (map_gridRead)  fill pass number          15  count =         2218
#  (map_gridRead)  fill pass number          16  count =         1582
#  (map_gridRead)  fill pass number          17  count =         1090
#  (map_gridRead)  fill pass number          18  count =          731
#  (map_gridRead)  fill pass number          19  count =          477
#  (map_gridRead)  fill pass number          20  count =          298
#  (map_gridRead)  fill pass number          21  count =          158
#  (map_gridRead)  fill pass number          22  count =           61
#  (map_gridRead)  fill pass number          23  count =           25
#  (map_gridRead)  fill pass number          24  count =            0
#  (map_print)  title    = gen_runoff mapping generation
#  (map_print)  normal   = conservative
#  (map_print)  method   = nearest neighbor smoothing
#  (map_print)  history  = history
#  (map_print)  conventn = NCAR-CCSM
#  (map_print)  domain_a =
#  /glade/campaign/cesm/cesmdata/inputdata/lnd/clm2/rtmdata/rdirc.05.061026
#  (map_print)  domain_b =
#  /glade/campaign/cgd/ppc/jiangzhu/setup_data/mom_topo/tx2_3v2_SCRIP_230415_21ka_
#  240518.nc
#
#  (map_print)  n_a    =       259200
#  (map_print)  ni_a   =          720
#  (map_print)  nj_a   =          360
#  (map_print)  dims_a =          720         360
#  (map_print)  xc_a   =   -179.750000000000        179.750000000000
#  (map_print)  yc_a   =   -89.7500000000000        89.7500000000000
#  (map_print)  xv_a   =   -180.000000000000        180.000000000000
#  (map_print)  yv_a   =   -90.0000000000000        90.0000000000000
#  (map_print)  mask_a =            1           1      259200
#  (map_print)  frac_a =    1.00000000000000        1.00000000000000
#    259200.000000000
#  (map_print)  area_a =   3.322850040127232E-007  7.615363001210512E-005
#    12.5664104887722
#
#  (map_print)  n_b    =       259200
#  (map_print)  ni_b   =          540
#  (map_print)  nj_b   =          480
#  (map_print)  dims_b =          540         480
#  (map_print)  xc_b   =   -286.999825265728        72.9998252657283
#  (map_print)  yc_b   =   -81.5581249317602        89.8568974054658
#  (map_print)  xv_b   =   -287.000000000000        73.0000000000000
#  (map_print)  yv_b   =   -81.6069197263629        89.9086289601051
#  (map_print)  mask_b =            0           1      137368
#  (map_print)  frac_b =   0.000000000000000E+000   1.00000000000000
#    137368.000000000
#  (map_print)  area_b =   1.506268200025600E-010  1.202411058318205E-004
#    12.4986014986094
#
#  (map_print)  n_s    =       259200
#  (map_print)  size S =       259200      259200      259200
#  (map_print)  S      =    1.00000000000000        1.00000000000000
#  (map_print)  ROW    =            1      259200
#  (map_print)  COL    =          -99         -99
#
#
#  (map_print)  Sample bin output, box number nibx,njbx =          360         180
# (map_print)  imin,imax,jmin,jmax =       1      1:    403    460:      1     72
# (map_print)  imin,imax,jmin,jmax =      73      1:    507     32:      1     85
# (map_print)  imin,imax,jmin,jmax =     145      1:     76    139:      1     81
# (map_print)  imin,imax,jmin,jmax =     217      1:    195    237:      1     45
# (map_print)  imin,imax,jmin,jmax =     289      1:    295    352:      1     72
# (map_print)  imin,imax,jmin,jmax =       1     37:    429    434:    125    134
# (map_print)  imin,imax,jmin,jmax =      73     37:    537      2:    125    134
# (map_print)  imin,imax,jmin,jmax =     145     37:    105    110:    125    134
# (map_print)  imin,imax,jmin,jmax =     217     37:    213    219:    125    134
# (map_print)  imin,imax,jmin,jmax =     289     37:    319    328:    123    136
# (map_print)  imin,imax,jmin,jmax =       1     73:    429    434:    195    201
# (map_print)  imin,imax,jmin,jmax =      73     73:    537      2:    195    201
# (map_print)  imin,imax,jmin,jmax =     145     73:    102    113:    192    205
# (map_print)  imin,imax,jmin,jmax =     217     73:    213    219:    195    201
# (map_print)  imin,imax,jmin,jmax =     289     73:    321    326:    195    201
# (map_print)  imin,imax,jmin,jmax =       1    109:    412    451:    279    335
# (map_print)  imin,imax,jmin,jmax =      73    109:    535      4:    309    318
# (map_print)  imin,imax,jmin,jmax =     145    109:    105    111:    310    316
# (map_print)  imin,imax,jmin,jmax =     217    109:    213    219:    310    316
# (map_print)  imin,imax,jmin,jmax =     289    109:    321    327:    310    316
# (map_print)  imin,imax,jmin,jmax =       1    145:    417    440:    367    403
# (map_print)  imin,imax,jmin,jmax =      73    145:    472     69:    363    480
# (map_print)  imin,imax,jmin,jmax =     145    145:    108    114:    379    388
# (map_print)  imin,imax,jmin,jmax =     217    145:    211    214:    385    390
# (map_print)  imin,imax,jmin,jmax =     289    145:    313    344:    366    416
#
#
#  (map_gennn0)       259200  unmasked src cells out of       259200  cells total
#  (map_gennn0) 2025-01-27 10:37:35 done            0  of       259200  cells
#            0 %
#  (map_gennn0) 2025-01-27 10:37:47 done         5184  of       259200  cells
#            2 %
#  (map_gennn0) 2025-01-27 10:38:00 done        10368  of       259200  cells
#            4 %
#  (map_gennn0) 2025-01-27 10:38:12 done        15552  of       259200  cells
#            6 %
#  (map_gennn0) 2025-01-27 10:38:25 done        20736  of       259200  cells
#            8 %
#  (map_gennn0) 2025-01-27 10:38:38 done        25920  of       259200  cells
#           10 %
#  (map_gennn0) 2025-01-27 10:38:50 done        31104  of       259200  cells
#           12 %
#  (map_gennn0) 2025-01-27 10:39:03 done        36288  of       259200  cells
#           14 %
#  (map_gennn0) 2025-01-27 10:39:15 done        41472  of       259200  cells
#           16 %
#  (map_gennn0) 2025-01-27 10:39:28 done        46656  of       259200  cells
#           18 %
#  (map_gennn0) 2025-01-27 10:39:41 done        51840  of       259200  cells
#           20 %
#  (map_gennn0) 2025-01-27 10:39:53 done        57024  of       259200  cells
#           22 %
#  (map_gennn0) 2025-01-27 10:40:06 done        62208  of       259200  cells
#           24 %
#  (map_gennn0) 2025-01-27 10:40:18 done        67392  of       259200  cells
#           26 %
#  (map_gennn0) 2025-01-27 10:40:31 done        72576  of       259200  cells
#           28 %
#  (map_gennn0) 2025-01-27 10:40:44 done        77760  of       259200  cells
#           30 %
#  (map_gennn0) 2025-01-27 10:40:56 done        82944  of       259200  cells
#           32 %
#  (map_gennn0) 2025-01-27 10:41:09 done        88128  of       259200  cells
#           34 %
#  (map_gennn0) 2025-01-27 10:41:21 done        93312  of       259200  cells
#           36 %
#  (map_gennn0) 2025-01-27 10:41:34 done        98496  of       259200  cells
#           38 %
#  (map_gennn0) 2025-01-27 10:41:47 done       103680  of       259200  cells
#           40 %
#  (map_gennn0) 2025-01-27 10:41:59 done       108864  of       259200  cells
#           42 %
#  (map_gennn0) 2025-01-27 10:42:12 done       114048  of       259200  cells
#           44 %
#  (map_gennn0) 2025-01-27 10:42:24 done       119232  of       259200  cells
#           46 %
#  (map_gennn0) 2025-01-27 10:42:37 done       124416  of       259200  cells
#           48 %
#  (map_gennn0) 2025-01-27 10:42:50 done       129600  of       259200  cells
#           50 %
#  (map_gennn0) 2025-01-27 10:43:02 done       134784  of       259200  cells
#           52 %
#  (map_gennn0) 2025-01-27 10:43:14 done       139968  of       259200  cells
#           54 %
#  (map_gennn0) 2025-01-27 10:43:26 done       145152  of       259200  cells
#           56 %
#  (map_gennn0) 2025-01-27 10:43:40 done       150336  of       259200  cells
#           58 %
#  (map_gennn0) 2025-01-27 10:43:52 done       155520  of       259200  cells
#           60 %
#  (map_gennn0) 2025-01-27 10:44:05 done       160704  of       259200  cells
#           62 %
#  (map_gennn0) 2025-01-27 10:44:17 done       165888  of       259200  cells
#           64 %
#  (map_gennn0) 2025-01-27 10:44:30 done       171072  of       259200  cells
#           66 %
#  (map_gennn0) 2025-01-27 10:44:43 done       176256  of       259200  cells
#           68 %
#  (map_gennn0) 2025-01-27 10:44:56 done       181440  of       259200  cells
#           70 %
#  (map_gennn0) 2025-01-27 10:45:08 done       186624  of       259200  cells
#           72 %
#  (map_gennn0) 2025-01-27 10:45:21 done       191808  of       259200  cells
#           74 %
#  (map_gennn0) 2025-01-27 10:45:33 done       196992  of       259200  cells
#           76 %
#  (map_gennn0) 2025-01-27 10:45:46 done       202176  of       259200  cells
#           78 %
#  (map_gennn0) 2025-01-27 10:45:59 done       207360  of       259200  cells
#           80 %
#  (map_gennn0) 2025-01-27 10:46:11 done       212544  of       259200  cells
#           82 %
#  (map_gennn0) 2025-01-27 10:46:24 done       217728  of       259200  cells
#           84 %
#  (map_gennn0) 2025-01-27 10:46:37 done       222912  of       259200  cells
#           86 %
#  (map_gennn0) 2025-01-27 10:46:50 done       228096  of       259200  cells
#           88 %
#  (map_gennn0) 2025-01-27 10:47:02 done       233280  of       259200  cells
#           90 %
#  (map_gennn0) 2025-01-27 10:47:15 done       238464  of       259200  cells
#           92 %
#  (map_gennn0) 2025-01-27 10:47:27 done       243648  of       259200  cells
#           94 %
#  (map_gennn0) 2025-01-27 10:47:40 done       248832  of       259200  cells
#           96 %
#  (map_gennn0) 2025-01-27 10:47:53 done       254016  of       259200  cells
#           98 %
# (shr_timer_print) timer  2:       1 calls,   630.352s, id: (map_gennn0) construct nearest neighbor map
# (mapsort_byrow) na, nb, ns =      259200     259200     259200
# (mapsort_byrow) min/max row =       20665     259084
# (mapsort_byrow) min/max col =           1     259200
# (mapsort_byrow) fill a temp matrix (non-standard format) with row-sorted data
# (mapsort_byrow) date & time: 2025-01-27  10:48:05
# (mapsort_byrow) max number of cols per row =        3218
# (mapsort_byrow) ... working, max elements, current element =      259200     100000
# (mapsort_byrow) ... working, max elements, current element =      259200     200000
# (mapsort_byrow) fill a input/output matrix with row-sorted data
# (mapsort_byrow) date & time: 2025-01-27  10:48:07
# (mapsort_checkSort) VERIFIED: rows are monotonically increasing
# (mapsort_checkSort) VERIFIED: cols are monotonically increasing
# (mapsort_byrow) sort columns within each row (assumes rows are sorted)
# (mapsort_byrow) date & time: 2025-01-27  10:48:07
# (mapsort_byrow) FYI: this routine is not threaded
# (mapsort_byrow) ... working on row      100000
# (mapsort_byrow) date & time: 2025-01-27  10:48:07
# (mapsort_byrow) ... working on row      200000
# (mapsort_byrow) date & time: 2025-01-27  10:48:07
# (mapsort_checkSort) VERIFIED: rows are monotonically increasing
# (mapsort_checkSort) VERIFIED: cols are monotonically increasing
# (mapsort_byrow) combine elements with same row/col (assumes matrix is sorted)
# (mapsort_byrow) date & time: 2025-01-27  10:48:07
# (mapsort_byrow) ... orig size of S =      259200
# (mapsort_byrow) ... new  size of S =      259200
# (mapsort_byrow) ... number of duplicate row/col =           0
# (mapsort_byrow) Done.
# (mapsort_byrow) date & time: 2025-01-27  10:48:07
# (map_check) ==============================================================
# (map_check) matrix title: gen_runoff mapping generation
# (map_check) n_s,n_a,n_b=     259200     259200     259200
# (map_check) --------------------------------------------------------------
# (map_check) check for correct row/column sorting
# (map_check) --------------------------------------------------------------
# (map_check) OK: row(:) is monotonically increasing
# (map_check) OK: for row=i, col(:) is monotonically increasing
# (map_check) Do S,row,col contain reasonable values?
# (map_check) col(:) min/max          1     259200
# (map_check) frac_a(:) min/max   1.0000000000   1.0000000000
# (map_check) row(:) min/max      20665     259084
# (map_check) frac_b(:) min/max   0.0000000000   1.0000000000
# (map_check) S(:)   min/max  1.402E-02  2.571E+00
# (map_check) Are col->row links unique? (assumes mapping is sorted)
# (map_check) OK, this matrix has unique col->row links
# (map_check) --------------------------------------------------------------
# (map_check) Definitive conservation check
# (map_check) --------------------------------------------------------------
# (map_check)  "correct column sum" means
# (map_check)   sum over i of S(i,j)*area_b(i) = area_a(j)
# (map_check)   number of columns                                   259200
# (map_check)   number of active columns                            259200
# (map_check)   number of active columns with correct sum           259200
# (map_check)   number of active columns with incorrect sum              0
# (map_check)   avg % error of incorrect sum                        0.000000
# (map_check)   max % error of incorrect sum                        0.000000
# (map_check)   number of active columns with no links                   0
# (map_check)   number of active columns with frac_a = 0.0               0
# (map_check)   number of active columns with 0.0<frac_a<1.0             0
# (map_check)   number of inactive columns                               0
# (map_check)   number of inactive columns with no links                 0
# (map_check)   number of inactive columns with some links               0
# (map_check)   number of rows                                      259200
# (map_check)   number of inactive rows with some links                  0
# (map_check) ==============================================================
# (shr_timer_print) timer  1:       1 calls,   633.165s, id: Step 1: Grid Read, Gen NN
# (main) -------------------------------------------------------------------------
# (main) Step 2:  create smoothing map
# (main) -------------------------------------------------------------------------
# (main)    eFold distance =  2.500000E+05
# (main)    rMax  distance =  2.500000E+05
#  (smooth_init)  orig matrix a-domain n active:       259200
#  (smooth_init)  orig matrix b-domain n active:       137368
#  (smooth_init)  orig matrix a-domain size    :       259200
#  (smooth_init)  orig matrix b-domain size    :       259200
#  (smooth_init)  orig matrix            ns    :       259200
#  (smooth_init)  smoothing matrix guess ns    :   2147000000
#  (smooth_init)  nactive                      =       102966
#  (smooth_init) number of source points is =        259200
#  (smooth_init) map_in%ns                  =        259200
# (map_DestGridRead) ocn data file = /glade/campaign/cgd/ppc/jiangzhu/setup_data/mom_topo/tx2_3v2_SCRIP_230415_21ka_240518.nc
# (smooth)  2025-01-27  10:49:02 j=   258001,  99.537% complete
# (smooth)  2025-01-27  10:49:02 j=   259001,  99.923% complete
# (smooth) done.
# (smooth) map n_s   =     8535735
# (smooth) min wgt          0.0000000E+00
# (smooth) max wgt          2.5014216E-05
# (smooth) wgtsum           4.6734699E-04
# (smooth) min S            1.6748198E-03
# (smooth) max S            3.0590232E-01
# (smooth) min row           20665
# (smooth) max row          259084
# (smooth) min col           20665
# (smooth) max col          259084
#  (smooth) min # dst cells per src cell =            5
#  (smooth) max # dst cells per src cell =          394
#  (smooth) avg # dst cells per src cell =           83
#  (smooth) # src cells smoothed to   0-  9 cells =            7
#  (smooth) # src cells smoothed to  10- 99 cells =        74354
#  (smooth) # src cells smoothed to 100-999 cells =        28605
#  (smooth) # src cells smoothed to   > 999 cells =            0
# (smooth) exit subroutine.
# (mapsort_byrow) na, nb, ns =      259200     259200    8535735
# (mapsort_byrow) min/max row =       20665     259084
# (mapsort_byrow) min/max col =       20665     259084
# (mapsort_byrow) fill a temp matrix (non-standard format) with row-sorted data
# (mapsort_byrow) date & time: 2025-01-27  10:49:02
# (mapsort_byrow) max number of cols per row =         149
# (mapsort_byrow) ... working, max elements, current element =     8535735     100000
# (mapsort_byrow) ... working, max elements, current element =     8535735     200000
# (mapsort_byrow) ... working, max elements, current element =     8535735     300000
# (mapsort_byrow) ... working, max elements, current element =     8535735     400000
# (mapsort_byrow) ... working, max elements, current element =     8535735     500000
# (mapsort_byrow) ... working, max elements, current element =     8535735     600000
# (mapsort_byrow) ... working, max elements, current element =     8535735     700000
# (mapsort_byrow) ... working, max elements, current element =     8535735     800000
# (mapsort_byrow) ... working, max elements, current element =     8535735     900000
# (mapsort_byrow) ... working, max elements, current element =     8535735    1000000
# (mapsort_byrow) ... working, max elements, current element =     8535735    1100000
# (mapsort_byrow) ... working, max elements, current element =     8535735    1200000
# (mapsort_byrow) ... working, max elements, current element =     8535735    1300000
# (mapsort_byrow) ... working, max elements, current element =     8535735    1400000
# (mapsort_byrow) ... working, max elements, current element =     8535735    1500000
# (mapsort_byrow) ... working, max elements, current element =     8535735    1600000
# (mapsort_byrow) ... working, max elements, current element =     8535735    1700000
# (mapsort_byrow) ... working, max elements, current element =     8535735    1800000
# (mapsort_byrow) ... working, max elements, current element =     8535735    1900000
# (mapsort_byrow) ... working, max elements, current element =     8535735    2000000
# (mapsort_byrow) ... working, max elements, current element =     8535735    2100000
# (mapsort_byrow) ... working, max elements, current element =     8535735    2200000
# (mapsort_byrow) ... working, max elements, current element =     8535735    2300000
# (mapsort_byrow) ... working, max elements, current element =     8535735    2400000
# (mapsort_byrow) ... working, max elements, current element =     8535735    2500000
# (mapsort_byrow) ... working, max elements, current element =     8535735    2600000
# (mapsort_byrow) ... working, max elements, current element =     8535735    2700000
# (mapsort_byrow) ... working, max elements, current element =     8535735    2800000
# (mapsort_byrow) ... working, max elements, current element =     8535735    2900000
# (mapsort_byrow) ... working, max elements, current element =     8535735    3000000
# (mapsort_byrow) ... working, max elements, current element =     8535735    3100000
# (mapsort_byrow) ... working, max elements, current element =     8535735    3200000
# (mapsort_byrow) ... working, max elements, current element =     8535735    3300000
# (mapsort_byrow) ... working, max elements, current element =     8535735    3400000
# (mapsort_byrow) ... working, max elements, current element =     8535735    3500000
# (mapsort_byrow) ... working, max elements, current element =     8535735    3600000
# (mapsort_byrow) ... working, max elements, current element =     8535735    3700000
# (mapsort_byrow) ... working, max elements, current element =     8535735    3800000
# (mapsort_byrow) ... working, max elements, current element =     8535735    3900000
# (mapsort_byrow) ... working, max elements, current element =     8535735    4000000
# (mapsort_byrow) ... working, max elements, current element =     8535735    4100000
# (mapsort_byrow) ... working, max elements, current element =     8535735    4200000
# (mapsort_byrow) ... working, max elements, current element =     8535735    4300000
# (mapsort_byrow) ... working, max elements, current element =     8535735    4400000
# (mapsort_byrow) ... working, max elements, current element =     8535735    4500000
# (mapsort_byrow) ... working, max elements, current element =     8535735    4600000
# (mapsort_byrow) ... working, max elements, current element =     8535735    4700000
# (mapsort_byrow) ... working, max elements, current element =     8535735    4800000
# (mapsort_byrow) ... working, max elements, current element =     8535735    4900000
# (mapsort_byrow) ... working, max elements, current element =     8535735    5000000
# (mapsort_byrow) ... working, max elements, current element =     8535735    5100000
# (mapsort_byrow) ... working, max elements, current element =     8535735    5200000
# (mapsort_byrow) ... working, max elements, current element =     8535735    5300000
# (mapsort_byrow) ... working, max elements, current element =     8535735    5400000
# (mapsort_byrow) ... working, max elements, current element =     8535735    5500000
# (mapsort_byrow) ... working, max elements, current element =     8535735    5600000
# (mapsort_byrow) ... working, max elements, current element =     8535735    5700000
# (mapsort_byrow) ... working, max elements, current element =     8535735    5800000
# (mapsort_byrow) ... working, max elements, current element =     8535735    5900000
# (mapsort_byrow) ... working, max elements, current element =     8535735    6000000
# (mapsort_byrow) ... working, max elements, current element =     8535735    6100000
# (mapsort_byrow) ... working, max elements, current element =     8535735    6200000
# (mapsort_byrow) ... working, max elements, current element =     8535735    6300000
# (mapsort_byrow) ... working, max elements, current element =     8535735    6400000
# (mapsort_byrow) ... working, max elements, current element =     8535735    6500000
# (mapsort_byrow) ... working, max elements, current element =     8535735    6600000
# (mapsort_byrow) ... working, max elements, current element =     8535735    6700000
# (mapsort_byrow) ... working, max elements, current element =     8535735    6800000
# (mapsort_byrow) ... working, max elements, current element =     8535735    6900000
# (mapsort_byrow) ... working, max elements, current element =     8535735    7000000
# (mapsort_byrow) ... working, max elements, current element =     8535735    7100000
# (mapsort_byrow) ... working, max elements, current element =     8535735    7200000
# (mapsort_byrow) ... working, max elements, current element =     8535735    7300000
# (mapsort_byrow) ... working, max elements, current element =     8535735    7400000
# (mapsort_byrow) ... working, max elements, current element =     8535735    7500000
# (mapsort_byrow) ... working, max elements, current element =     8535735    7600000
# (mapsort_byrow) ... working, max elements, current element =     8535735    7700000
# (mapsort_byrow) ... working, max elements, current element =     8535735    7800000
# (mapsort_byrow) ... working, max elements, current element =     8535735    7900000
# (mapsort_byrow) ... working, max elements, current element =     8535735    8000000
# (mapsort_byrow) ... working, max elements, current element =     8535735    8100000
# (mapsort_byrow) ... working, max elements, current element =     8535735    8200000
# (mapsort_byrow) ... working, max elements, current element =     8535735    8300000
# (mapsort_byrow) ... working, max elements, current element =     8535735    8400000
# (mapsort_byrow) ... working, max elements, current element =     8535735    8500000
# (mapsort_byrow) fill a input/output matrix with row-sorted data
# (mapsort_byrow) date & time: 2025-01-27  10:49:02
# (mapsort_checkSort) VERIFIED: rows are monotonically increasing
# (mapsort_checkSort) VERIFIED: cols are monotonically increasing
# (mapsort_byrow) sort columns within each row (assumes rows are sorted)
# (mapsort_byrow) date & time: 2025-01-27  10:49:02
# (mapsort_byrow) FYI: this routine is not threaded
# (mapsort_byrow) ... working on row      100000
# (mapsort_byrow) date & time: 2025-01-27  10:49:02
# (mapsort_byrow) ... working on row      200000
# (mapsort_byrow) date & time: 2025-01-27  10:49:02
# (mapsort_checkSort) VERIFIED: rows are monotonically increasing
# (mapsort_checkSort) VERIFIED: cols are monotonically increasing
# (mapsort_byrow) combine elements with same row/col (assumes matrix is sorted)
# (mapsort_byrow) date & time: 2025-01-27  10:49:02
# (mapsort_byrow) ... orig size of S =     8535735
# (mapsort_byrow) ... new  size of S =     8535735
# (mapsort_byrow) ... number of duplicate row/col =           0
# (mapsort_byrow) Done.
# (mapsort_byrow) date & time: 2025-01-27  10:49:02
# (map_check) ==============================================================
# (map_check) matrix title: CCSM conservative smoothing map
# (map_check) n_s,n_a,n_b=    8535735     259200     259200
# (map_check) --------------------------------------------------------------
# (map_check) check for correct row/column sorting
# (map_check) --------------------------------------------------------------
# (map_check) OK: row(:) is monotonically increasing
# (map_check) OK: for row=i, col(:) is monotonically increasing
# (map_check) Do S,row,col contain reasonable values?
# (map_check) col(:) min/max      20665     259084
# (map_check) frac_a(:) min/max   1.0000000000   1.0000000000
# (map_check) row(:) min/max      20665     259084
# (map_check) frac_b(:) min/max   1.0000000000   1.0000000000
# (map_check) S(:)   min/max  1.675E-03  3.059E-01
# (map_check) Are col->row links unique? (assumes mapping is sorted)
# (map_check) OK, this matrix has unique col->row links
# (map_check) --------------------------------------------------------------
# (map_check) Definitive conservation check
# (map_check) --------------------------------------------------------------
# (map_check)  "correct column sum" means
# (map_check)   sum over i of S(i,j)*area_b(i) = area_a(j)
# (map_check)   number of columns                                   259200
# (map_check)   number of active columns                            102966
# (map_check)   number of active columns with correct sum           102966
# (map_check)   number of active columns with incorrect sum              0
# (map_check)   avg % error of incorrect sum                        0.000000
# (map_check)   max % error of incorrect sum                        0.000000
# (map_check)   number of active columns with no links                   0
# (map_check)   number of active columns with frac_a = 0.0               0
# (map_check)   number of active columns with 0.0<frac_a<1.0             0
# (map_check)   number of inactive columns                          156234
# (map_check)   number of inactive columns with no links            156234
# (map_check)   number of inactive columns with some links               0
# (map_check)   number of rows                                      259200
# (map_check)   number of inactive rows with some links                  0
# (map_check) ==============================================================
# (shr_timer_print) timer  3:       1 calls,    55.497s, id: Step 2: Create the smoothing map
# (main) -------------------------------------------------------------------------
# (main) Step 3:  create smoothed version of nearest neighbor  map
# (main) -------------------------------------------------------------------------
# <map_matMatMult> FYI: this routine is not threaded
# <map_matMatMult> matrix-matrix multiply: B = S*A
# <map_matMatMult> do i=1 to number rows in matrix S:    259200
# <map_matMatMult> do i=k to number cols in matrix A:    259200
# <map_matMatMult> Estimated number of non-zeros in B:   19454900
#  (map_matMatMult)  done         5184  of       259200 ....           2  percent
#  (map_matMatMult)  done        10368  of       259200 ....           4  percent
#  (map_matMatMult)  done        15552  of       259200 ....           6  percent
#  (map_matMatMult)  done        20736  of       259200 ....           8  percent
#  (map_matMatMult)  done        25920  of       259200 ....          10  percent
#  (map_matMatMult)  done        31104  of       259200 ....          12  percent
#  (map_matMatMult)  done        36288  of       259200 ....          14  percent
#  (map_matMatMult)  done        41472  of       259200 ....          16  percent
#  (map_matMatMult)  done        46656  of       259200 ....          18  percent
#  (map_matMatMult)  done        51840  of       259200 ....          20  percent
# ...
# (mapsort_byrow) ... working, max elements, current element =   211919357  198300000
# (mapsort_byrow) ... working, max elements, current element =   211919357  198400000
# (mapsort_byrow) ... working, max elements, current element =   211919357  198500000
# (mapsort_byrow) ... working, max elements, current element =   211919357  198600000
# (mapsort_byrow) ... working, max elements, current element =   211919357  198700000
# (mapsort_byrow) ... working, max elements, current element =   211919357  198800000
# (mapsort_byrow) ... working, max elements, current element =   211919357  198900000
# (mapsort_byrow) ... working, max elements, current element =   211919357  199000000
# (mapsort_byrow) ... working, max elements, current element =   211919357  199100000
# (mapsort_byrow) ... working, max elements, current element =   211919357  199200000
# (mapsort_byrow) ... working, max elements, current element =   211919357  199300000
# (mapsort_byrow) ... working, max elements, current element =   211919357  199400000
# (mapsort_byrow) ... working, max elements, current element =   211919357  199500000
# (mapsort_byrow) ... working, max elements, current element =   211919357  199600000
# (mapsort_byrow) ... working, max elements, current element =   211919357  199700000
# (mapsort_byrow) ... working, max elements, current element =   211919357  199800000
# (mapsort_byrow) ... working, max elements, current element =   211919357  199900000
# (mapsort_byrow) ... working, max elements, current element =   211919357  200000000
# (mapsort_byrow) ... working, max elements, current element =   211919357  200100000
# (mapsort_byrow) ... working, max elements, current element =   211919357  200200000
# (mapsort_byrow) ... working, max elements, current element =   211919357  200300000
# (mapsort_byrow) ... working, max elements, current element =   211919357  200400000
# (mapsort_byrow) ... working, max elements, current element =   211919357  200500000
# (mapsort_byrow) ... working, max elements, current element =   211919357  200600000
# (mapsort_byrow) ... working, max elements, current element =   211919357  200700000
# (mapsort_byrow) ... working, max elements, current element =   211919357  200800000
# (mapsort_byrow) ... working, max elements, current element =   211919357  200900000
# (mapsort_byrow) ... working, max elements, current element =   211919357  201000000
# (mapsort_byrow) ... working, max elements, current element =   211919357  201100000
# (mapsort_byrow) ... working, max elements, current element =   211919357  201200000
# (mapsort_byrow) ... working, max elements, current element =   211919357  201300000
# (mapsort_byrow) ... working, max elements, current element =   211919357  201400000
# (mapsort_byrow) ... working, max elements, current element =   211919357  201500000
# (mapsort_byrow) ... working, max elements, current element =   211919357  201600000
# (mapsort_byrow) ... working, max elements, current element =   211919357  201700000
# (mapsort_byrow) ... working, max elements, current element =   211919357  201800000
# (mapsort_byrow) ... working, max elements, current element =   211919357  201900000
# (mapsort_byrow) ... working, max elements, current element =   211919357  202000000
# (mapsort_byrow) ... working, max elements, current element =   211919357  202100000
# (mapsort_byrow) ... working, max elements, current element =   211919357  202200000
# (mapsort_byrow) ... working, max elements, current element =   211919357  202300000
# (mapsort_byrow) ... working, max elements, current element =   211919357  202400000
# (mapsort_byrow) ... working, max elements, current element =   211919357  202500000
# (mapsort_byrow) ... working, max elements, current element =   211919357  202600000
# (mapsort_byrow) ... working, max elements, current element =   211919357  202700000
# (mapsort_byrow) ... working, max elements, current element =   211919357  202800000
# (mapsort_byrow) ... working, max elements, current element =   211919357  202900000
# (mapsort_byrow) ... working, max elements, current element =   211919357  203000000
# (mapsort_byrow) ... working, max elements, current element =   211919357  203100000
# (mapsort_byrow) ... working, max elements, current element =   211919357  203200000
# (mapsort_byrow) ... working, max elements, current element =   211919357  203300000
# (mapsort_byrow) ... working, max elements, current element =   211919357  203400000
# (mapsort_byrow) ... working, max elements, current element =   211919357  203500000
# (mapsort_byrow) ... working, max elements, current element =   211919357  203600000
# (mapsort_byrow) ... working, max elements, current element =   211919357  203700000
# (mapsort_byrow) ... working, max elements, current element =   211919357  203800000
# (mapsort_byrow) ... working, max elements, current element =   211919357  203900000
# (mapsort_byrow) ... working, max elements, current element =   211919357  204000000
# (mapsort_byrow) ... working, max elements, current element =   211919357  204100000
# (mapsort_byrow) ... working, max elements, current element =   211919357  204200000
# (mapsort_byrow) ... working, max elements, current element =   211919357  204300000
# (mapsort_byrow) ... working, max elements, current element =   211919357  204400000
# (mapsort_byrow) ... working, max elements, current element =   211919357  204500000
# (mapsort_byrow) ... working, max elements, current element =   211919357  204600000
# (mapsort_byrow) ... working, max elements, current element =   211919357  204700000
# (mapsort_byrow) ... working, max elements, current element =   211919357  204800000
# (mapsort_byrow) ... working, max elements, current element =   211919357  204900000
# (mapsort_byrow) ... working, max elements, current element =   211919357  205000000
# (mapsort_byrow) ... working, max elements, current element =   211919357  205100000
# (mapsort_byrow) ... working, max elements, current element =   211919357  205200000
# (mapsort_byrow) ... working, max elements, current element =   211919357  205300000
# (mapsort_byrow) ... working, max elements, current element =   211919357  205400000
# (mapsort_byrow) ... working, max elements, current element =   211919357  205500000
# (mapsort_byrow) ... working, max elements, current element =   211919357  205600000
# (mapsort_byrow) ... working, max elements, current element =   211919357  205700000
# (mapsort_byrow) ... working, max elements, current element =   211919357  205800000
# (mapsort_byrow) ... working, max elements, current element =   211919357  205900000
# (mapsort_byrow) ... working, max elements, current element =   211919357  206000000
# (mapsort_byrow) ... working, max elements, current element =   211919357  206100000
# (mapsort_byrow) ... working, max elements, current element =   211919357  206200000
# (mapsort_byrow) ... working, max elements, current element =   211919357  206300000
# (mapsort_byrow) ... working, max elements, current element =   211919357  206400000
# (mapsort_byrow) ... working, max elements, current element =   211919357  206500000
# (mapsort_byrow) ... working, max elements, current element =   211919357  206600000
# (mapsort_byrow) ... working, max elements, current element =   211919357  206700000
# (mapsort_byrow) ... working, max elements, current element =   211919357  206800000
# (mapsort_byrow) ... working, max elements, current element =   211919357  206900000
# (mapsort_byrow) ... working, max elements, current element =   211919357  207000000
# (mapsort_byrow) ... working, max elements, current element =   211919357  207100000
# (mapsort_byrow) ... working, max elements, current element =   211919357  207200000
# (mapsort_byrow) ... working, max elements, current element =   211919357  207300000
# (mapsort_byrow) ... working, max elements, current element =   211919357  207400000
# (mapsort_byrow) ... working, max elements, current element =   211919357  207500000
# (mapsort_byrow) ... working, max elements, current element =   211919357  207600000
# (mapsort_byrow) ... working, max elements, current element =   211919357  207700000
# (mapsort_byrow) ... working, max elements, current element =   211919357  207800000
# (mapsort_byrow) ... working, max elements, current element =   211919357  207900000
# (mapsort_byrow) ... working, max elements, current element =   211919357  208000000
# (mapsort_byrow) ... working, max elements, current element =   211919357  208100000
# (mapsort_byrow) ... working, max elements, current element =   211919357  208200000
# (mapsort_byrow) ... working, max elements, current element =   211919357  208300000
# (mapsort_byrow) ... working, max elements, current element =   211919357  208400000
# (mapsort_byrow) ... working, max elements, current element =   211919357  208500000
# (mapsort_byrow) ... working, max elements, current element =   211919357  208600000
# (mapsort_byrow) ... working, max elements, current element =   211919357  208700000
# (mapsort_byrow) ... working, max elements, current element =   211919357  208800000
# (mapsort_byrow) ... working, max elements, current element =   211919357  208900000
# (mapsort_byrow) ... working, max elements, current element =   211919357  209000000
# (mapsort_byrow) ... working, max elements, current element =   211919357  209100000
# (mapsort_byrow) ... working, max elements, current element =   211919357  209200000
# (mapsort_byrow) ... working, max elements, current element =   211919357  209300000
# (mapsort_byrow) ... working, max elements, current element =   211919357  209400000
# (mapsort_byrow) ... working, max elements, current element =   211919357  209500000
# (mapsort_byrow) ... working, max elements, current element =   211919357  209600000
# (mapsort_byrow) ... working, max elements, current element =   211919357  209700000
# (mapsort_byrow) ... working, max elements, current element =   211919357  209800000
# (mapsort_byrow) ... working, max elements, current element =   211919357  209900000
# (mapsort_byrow) ... working, max elements, current element =   211919357  210000000
# (mapsort_byrow) ... working, max elements, current element =   211919357  210100000
# (mapsort_byrow) ... working, max elements, current element =   211919357  210200000
# (mapsort_byrow) ... working, max elements, current element =   211919357  210300000
# (mapsort_byrow) ... working, max elements, current element =   211919357  210400000
# (mapsort_byrow) ... working, max elements, current element =   211919357  210500000
# (mapsort_byrow) ... working, max elements, current element =   211919357  210600000
# (mapsort_byrow) ... working, max elements, current element =   211919357  210700000
# (mapsort_byrow) ... working, max elements, current element =   211919357  210800000
# (mapsort_byrow) ... working, max elements, current element =   211919357  210900000
# (mapsort_byrow) ... working, max elements, current element =   211919357  211000000
# (mapsort_byrow) ... working, max elements, current element =   211919357  211100000
# (mapsort_byrow) ... working, max elements, current element =   211919357  211200000
# (mapsort_byrow) ... working, max elements, current element =   211919357  211300000
# (mapsort_byrow) ... working, max elements, current element =   211919357  211400000
# (mapsort_byrow) ... working, max elements, current element =   211919357  211500000
# (mapsort_byrow) ... working, max elements, current element =   211919357  211600000
# (mapsort_byrow) ... working, max elements, current element =   211919357  211700000
# (mapsort_byrow) ... working, max elements, current element =   211919357  211800000
# (mapsort_byrow) ... working, max elements, current element =   211919357  211900000
# (mapsort_byrow) fill a input/output matrix with row-sorted data
# (mapsort_byrow) date & time: 2025-01-27  11:01:46
# (mapsort_checkSort) VERIFIED: rows are monotonically increasing
# (mapsort_checkSort) WARNING : cols are not monotonically increasing
# (mapsort_byrow) sort columns within each row (assumes rows are sorted)
# (mapsort_byrow) date & time: 2025-01-27  11:01:49
# (mapsort_byrow) FYI: this routine is not threaded
# (mapsort_byrow) ... working on row      100000
# (mapsort_byrow) date & time: 2025-01-27  11:03:05
# (mapsort_byrow) ... working on row      200000
# (mapsort_byrow) date & time: 2025-01-27  11:03:12
# (mapsort_checkSort) VERIFIED: rows are monotonically increasing
# (mapsort_checkSort) VERIFIED: cols are monotonically increasing
# (mapsort_byrow) combine elements with same row/col (assumes matrix is sorted)
# (mapsort_byrow) date & time: 2025-01-27  11:05:12
# (mapsort_byrow) ... orig size of S =   211919357
# (mapsort_byrow) ... new  size of S =   211919357
# (mapsort_byrow) ... number of duplicate row/col =           0
# (mapsort_byrow) Done.
# (mapsort_byrow) date & time: 2025-01-27  11:05:14
# (map_check) ==============================================================
# (map_check) matrix title: runoff map: r05 -> tx2_3v2 21ka, nearest neighbor and smoothed
# (map_check) n_s,n_a,n_b=  211919357     259200     259200
# (map_check) --------------------------------------------------------------
# (map_check) check for correct row/column sorting
# (map_check) --------------------------------------------------------------
# (map_check) OK: row(:) is monotonically increasing
# (map_check) OK: for row=i, col(:) is monotonically increasing
# (map_check) Do S,row,col contain reasonable values?
# (map_check) col(:) min/max          1     259200
# (map_check) frac_a(:) min/max   1.0000000000   1.0000000000
# (map_check) row(:) min/max      20665     259084
# (map_check) frac_b(:) min/max   1.0000000000   1.0000000000
# (map_check) S(:)   min/max  8.246E-06  4.231E-02
# (map_check) Are col->row links unique? (assumes mapping is sorted)
# (map_check) OK, this matrix has unique col->row links
# (map_check) --------------------------------------------------------------
# (map_check) Definitive conservation check
# (map_check) --------------------------------------------------------------
# (map_check)  "correct column sum" means
# (map_check)   sum over i of S(i,j)*area_b(i) = area_a(j)
# (map_check)   number of columns                                   259200
# (map_check)   number of active columns                            259200
# (map_check)   number of active columns with correct sum           259200
# (map_check)   number of active columns with incorrect sum              0
# (map_check)   avg % error of incorrect sum                        0.000000
# (map_check)   max % error of incorrect sum                        0.000000
# (map_check)   number of active columns with no links                   0
# (map_check)   number of active columns with frac_a = 0.0               0
# (map_check)   number of active columns with 0.0<frac_a<1.0             0
# (map_check)   number of inactive columns                               0
# (map_check)   number of inactive columns with no links                 0
# (map_check)   number of inactive columns with some links               0
# (map_check)   number of rows                                      259200
# (map_check)   number of inactive rows with some links                  0
# (map_check) ==============================================================
# (shr_timer_print) timer  5:       1 calls,   245.360s, id: Step 3:  Matrix Multiply
# (shr_timer_print_all) print all timing info:
# (shr_timer_print) timer  1:       1 calls,   668.254s, id: Step 1: Grid Read, Gen NN
# (shr_timer_print) timer  2:       1 calls,   665.432s, id: (map_gennn0) construct nearest neighbor map
# (shr_timer_print) timer  3:       1 calls,    69.709s, id: Step 2: Create the smoothing map
# (shr_timer_print) timer  4:       1 calls,    49.419s, id: (smooth) compute smoothing matrix
# (shr_timer_print) timer  5:       1 calls,   245.360s, id: Step 3:  Matrix Multiply
# (shr_timer_print) timer  6:       1 calls,     6.439s, id: (map_matMatMult) matrix multiply - all
# (shr_timer_print) timer  7:       0 calls,     0.000s, id: (map_matMatMult) matrix multiply - 100k rows
# CPU times: user 457 ms, sys: 138 ms, total: 595 ms
# Wall time: 27min 59s
