# %% [markdown]
# ---
# # Create CAM7 topography file for CESM3 LGM
# - Author: Jiang Zhu (jiangzhu@ucar.edu)
# - Tools used
#   - [NCAR_Topo](https://github.com/NCAR/Topo) by Peter Lauritzen
#   - [UXarray](https://uxarray.readthedocs.io/en/latest/) (only used for visualization)
# - Notes: I ran the notebook on Casper and used 100 GB memory.
# ---

# %%
import subprocess
import re
import os
from datetime import date

import hvplot.xarray
import xarray as xr
import uxarray as ux
import numpy as np
import matplotlib.pyplot as plt
import metpy.calc as mpcalc
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='a4a3d34b-aff1-4f7e-9189-5838023ef2b2'>
#   <div id="eeb7fc19-1534-4eb0-b24a-9af30a716f33" data-root-id="a4a3d34b-aff1-4f7e-9189-5838023ef2b2" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"392f2830-21bc-4196-87d9-3327d0b00520":{"version":"3.7.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"a4a3d34b-aff1-4f7e-9189-5838023ef2b2"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"0e2a1e68-70c0-418a-9cf4-e89335917e82","attributes":{"plot_id":"a4a3d34b-aff1-4f7e-9189-5838023ef2b2","comm_id":"ea0944e57b384c3bbacf73b36d3d7326","client_comm_id":"24c432317f8e437fae7dba27f900502a"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","defaul ...
#   var render_items = [{"docid":"392f2830-21bc-4196-87d9-3327d0b00520","roots":{"a4a3d34b-aff1-4f7e-9189-5838023ef2b2":"eeb7fc19-1534-4eb0-b24a-9af30a716f33"},"root_ids":["a4a3d34b-aff1-4f7e-9189-5838023ef2b2"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# ---
# ## Input: raw boundary condition data
# ### PlioMIP3 data in 1deg resolution

# %%
plio_dir = '/glade/campaign/cesm/development/palwg/raw_boundary_data/pliomip3'

plio_fnames = [
    f'{plio_dir}/LP_exp_data/LP_topo_v1.0.nc',
    f'{plio_dir}/LP_exp_data/LP_LSM_v1.0.nc',
]

prei_fnames = [
    f'{plio_dir}/Modern_std_exp_data/Modern_std_topo_v1.0.nc',
    f'{plio_dir}/Modern_std_exp_data/Modern_std_LSM_v1.0.nc',
]

print(*(plio_fnames + prei_fnames), sep="\n")
# Out:
# /glade/campaign/cesm/development/palwg/raw_boundary_data/pliomip3/LP_exp_data/LP_topo_v1.0.nc
# /glade/campaign/cesm/development/palwg/raw_boundary_data/pliomip3/LP_exp_data/LP_LSM_v1.0.nc
# /glade/campaign/cesm/development/palwg/raw_boundary_data/pliomip3/Modern_std_exp_data/Modern_std_topo_v1.0.nc
# /glade/campaign/cesm/development/palwg/raw_boundary_data/pliomip3/Modern_std_exp_data/Modern_std_LSM_v1.0.nc

# %% [markdown]
# ### Preindustrial topo in 30" resolution

# %%
gmted_dir = '/glade/campaign/cesm/development/palwg/raw_boundary_data/gmted2010'
gmted_fname = 'gmted2010_modis_bedmachine-rawdata-220518.nc'

gmted = f"{gmted_dir}/{gmted_fname}"

print(gmted)
# Out:
# /glade/campaign/cesm/development/palwg/raw_boundary_data/gmted2010/gmted2010_modis_bedmachine-rawdata-220518.nc

# %% [markdown]
# ---
# ## Grid configurations: Target grid SCRIP files,  smoothing scales, etc

# %%
greenlndantarcsgh30_fac = 2.5
source_data_identifier = 'pliomip3_lp'

target_grids = {
    'ne30pg3': {
        'smoothing_scale': 100,
        'scrip_file': '/glade/campaign/cesm/cesmdata/inputdata/share/scripgrids/ne30pg3_scrip_170417.nc',
        'scrip_file_gll': '/glade/campaign/cesm/cesmdata/inputdata/share/scripgrids/ne30np4_091226_pentagons.nc',
        'topo_pre': '/glade/campaign/cgd/amp/pel/topo/cesm3/ne30pg3_gmted2010_modis_bedmachine_nc3000_Laplace0100_noleak_greenlndantarcsgh30fac2.50_20250814.nc',
    },
    'ne16pg3': {
        'smoothing_scale': 200,
        'scrip_file': '/glade/campaign/cesm/cesmdata/inputdata/share/scripgrids/ne16pg3_scrip_170429.nc',
        'scrip_file_gll': '/glade/campaign/cesm/cesmdata/inputdata/share/scripgrids/ne16np4_scrip_171002.nc',
        'topo_pre': '/glade/campaign/cgd/ppc/jiangzhu/setup_data/cam_topo/pi/ne16pg3_gmted2010_modis_bedmachine_nc3000_Laplace0200_noleak_greenlndantarcsgh30fac2.50_20250817.nc',
    },
    'fv0.9x1.25': {
        'smoothing_scale': 100,
        'scrip_file': '/glade/campaign/cesm/cesmdata/inputdata/share/scripgrids/fv0.9x1.25_141008.nc',
        'topo_pre': '/glade/campaign/cgd/ppc/jiangzhu/setup_data/cam_topo/pi/fv0.9x1.25_gmted2010_modis_bedmachine_nc3000_Laplace0100_noleak_greenlndantarcsgh30fac2.50_20250817.nc',
    },
    'fv1.9x2.5': {
        'smoothing_scale': 200,
        'scrip_file': '/glade/campaign/cesm/cesmdata/inputdata/share/scripgrids/fv1.9x2.5_141008.nc',
        'topo_pre': '/glade/campaign/cgd/ppc/jiangzhu/setup_data/cam_topo/pi/fv1.9x2.5_gmted2010_modis_bedmachine_nc3000_Laplace0200_noleak_greenlndantarcsgh30fac2.50_20250818.nc',
    }
}

# %%
# Subset grids to create cam topo files

target_grids = {
    key: target_grids[key]
    for key in ['fv1.9x2.5']
    # for key in ['ne30pg3', 'fv1.9x2.5', 'fv0.9x1.25']
    if key in target_grids
}

# %% [markdown]
# ---
# ## Output

# %%
today = date.today().strftime("%Y%m%d")
print(today)

work_dir = '/glade/derecho/scratch/jiangzhu/setup_data/pliomip3'
subprocess.run(f"mkdir -p {work_dir}", shell=True)
# Out:
# 20250830
# CompletedProcess(args='mkdir -p /glade/derecho/scratch/jiangzhu/setup_data/pliomip3', returncode=0)

# %%
for grid, config in target_grids.items():
    smoothing_scale = config['smoothing_scale']
    target_grids[grid] = {
        **config,
        'topo_plio': f"{work_dir}/{grid}_{source_data_identifier}_nc3000_Laplace{smoothing_scale:04d}_noleak_greenlndantarcsgh30fac{greenlndantarcsgh30_fac:.2f}_{today}.nc",
    }

# %% [markdown]
# ---
# ### Intermediate output files

# %%
gmted_plio_fname = f"gmted2010_modis_bedmachine-rawdata-220518_{source_data_identifier}_{today}.nc"
gmted_plio = f"{work_dir}/{gmted_plio_fname}"

ncube3000_plio_fname = f"gmted2010_modis_bedmachine-rawdata-220518_{source_data_identifier}_ncube3000_{today}.nc"
ncube3000_plio = f"{work_dir}/{ncube3000_plio_fname}"

print(gmted_plio)
print(ncube3000_plio)
# Out:
# /glade/derecho/scratch/jiangzhu/setup_data/pliomip3/gmted2010_modis_bedmachine-rawdata-220518_pliomip3_lp_20250830.nc
# /glade/derecho/scratch/jiangzhu/setup_data/pliomip3/gmted2010_modis_bedmachine-rawdata-220518_pliomip3_lp_ncube3000_20250830.nc

# %% [markdown]
# ---
# ## Tools used: NCAR Topo
# - Create soft links of executables in the work directory.

# %%
ncar_topo_dir = '/glade/campaign/cesm/development/palwg/scripts/setup/ncar_topo'

src_bin_to_cube = f"{ncar_topo_dir}/bin_to_cube/bin_to_cube_casper"
src_cube_to_target = f"{ncar_topo_dir}/cube_to_target/cube_to_target_casper"

subprocess.run(
    ["ln", "-sfn", src_bin_to_cube, f"{work_dir}/bin_to_cube"],
    check=True)

subprocess.run(
    ["ln", "-sfn", src_cube_to_target, f"{work_dir}/cube_to_target"],
    check=True)
# Out:
# CompletedProcess(args=['ln', '-sfn', '/glade/campaign/cesm/development/palwg/scripts/setup/ncar_topo/cube_to_target/cube_to_target_casper', '/glade/derecho/scratch/jiangzhu/setup_data/pliomip3/cube_to_target'], returncode=0)

# %% [markdown]
# ---
# ## Step 1: compute Late Pliocene topo by adding PlioMIP3 anomaly to modern gmted
# - Input: PlioMIP3 topo files
# - Input: `gmted`, modern-day hires topography file in 30' resolution
# - Output: `gmted_plio`, Late Pliocene hires topography file in 30' resolution

# %% [markdown]
# ### Read preindustrial & Late Pliocene topo from PlioMIP3

# %%
ds_plio = xr.open_mfdataset(plio_fnames)
ds_plio = ds_plio.rename({'p4_topo': 'topo', 'p4_lsm': 'lsm'})
ds_plio
# Out:
# <xarray.Dataset> Size: 521kB
# Dimensions:  (lat: 180, lon: 360)
# Coordinates:
#   * lat      (lat) float32 720B -89.5 -88.5 -87.5 -86.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float32 1kB -179.5 -178.5 -177.5 -176.5 ... 177.5 178.5 179.5
# Data variables:
#     topo     (lat, lon) float32 259kB dask.array<chunksize=(180, 360), meta=np.ndarray>
#     lsm      (lat, lon) float32 259kB dask.array<chunksize=(180, 360), meta=np.ndarray>
# Attributes:
#     Email:                 J.C.Tindall@leeds.ac.uk
#     Information:           This is the PRISM4 Pliocene topography as presente...
#     Institution:           University of Leeds
#     Netcdf_Creation_Date:  2023-08-22
#     Netcdf_author:         Tindall, J. C.
#     Conventions:           CF-1.7

# %%
ds_prei = xr.open_mfdataset(prei_fnames)
ds_prei = ds_prei.rename({'etopo1_topo': 'topo', 'etopo1_lsm': 'lsm'})
ds_prei
# Out:
# <xarray.Dataset> Size: 521kB
# Dimensions:  (lat: 180, lon: 360)
# Coordinates:
#   * lat      (lat) float32 720B -89.5 -88.5 -87.5 -86.5 ... 86.5 87.5 88.5 89.5
#   * lon      (lon) float32 1kB -179.5 -178.5 -177.5 -176.5 ... 177.5 178.5 179.5
# Data variables:
#     topo     (lat, lon) float32 259kB dask.array<chunksize=(180, 360), meta=np.ndarray>
#     lsm      (lat, lon) float32 259kB dask.array<chunksize=(180, 360), meta=np.ndarray>
# Attributes:
#     Email:                 J.C.Tindall@leeds.ac.uk
#     Information:           Etopo1 Data originally downloaded from www.ngdc.no...
#     Institution:           University of Leeds
#     Netcdf_Creation_Date:  2023-08-08
#     Netcdf_author:         Tindall, J. C.
#     Conventions:           CF-1.7

# %% [markdown]
# ### Do not change topography over ocean

# %%
dsa = ds_plio - ds_prei

dsa['topo'] = xr.where(
    (ds_plio.lsm > 0) | (ds_prei.lsm > 0), dsa.topo, 0)

print(f"Maximum landfrac increase: {dsa.lsm.max().values}")
print(f"Maximum landfrac decrease: {dsa.lsm.min().values}")
print(f"Maximum elevation increase (m): {dsa.topo.max().values}")
print(f"Maximum elevation decrease (m): {dsa.topo.min().values}")
# Out:
# Maximum landfrac increase: 1.0
# Maximum landfrac decrease: -1.0
# Maximum elevation increase (m): 1361.0
# Maximum elevation decrease (m): -3387.0

# %% [markdown]
# ### Create a new landm_coslat for CAM4
# - This is needed for running NCAR TOPO but it is only used for CAM4

# %%
# Load and smooth land mask
lsm = ds_plio.lsm.load()

# Iterative smoothing - only smooth partial land/ocean areas
for i in range(11):
    smoothed = mpcalc.smooth_n_point(lsm, 9)
    lsm = xr.where(lsm < 1, smoothed, lsm)

# Apply cosine latitude weighting, preserve pure land points
cos_weight = np.cos(np.radians(ds_plio.lat))
landm_coslat = xr.where(ds_plio.lsm >= 1, ds_plio.lsm, lsm * cos_weight)

# Save to file
landm_file = f"{work_dir}/landm_coslat.nc"
if os.path.exists(landm_file):
    subprocess.run(["rm", "-f", landm_file], check=True)

landm_coslat.to_dataset(name="LANDM_COSLAT").to_netcdf(landm_file)

landm_coslat.plot(size=2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 18
#      15 if os.path.exists(landm_coslat):
#      16     subprocess.run(["rm", "-f", landm_coslat], check=True)
# ---> 18 landm_coslat.to_dataset(name="LANDM_COSLAT").to_netcdf(landm_coslat)
#      20 landm_coslat.plot(size=2)
#
# AttributeError: 'str' object has no attribute 'to_dataset'

# %% [markdown]
# ### Make plots

# %%
fig, axes = plt.subplots(2, 2, figsize=(8, 4),
                         sharex=True, sharey=True,
                         constrained_layout=True)

for vname, ax in zip(['topo', 'lsm'], axes[0, :]):
    ds_plio[vname].plot.pcolormesh(ax=ax)
    ax.set_title(f"Late Pliocene: {vname}")

for vname, ax in zip(['topo', 'lsm'], axes[1, :]):
    dsa[vname].plot.pcolormesh(ax=ax)
    ax.set_title(f"Late Pliocene difference: {vname}")

# %% [markdown]
# ### Read preindustrial topo in high res.
# - NOTE: landfract is a binary land-sea mask containing 0 and 1

# %%
gmted_ds = xr.open_dataset(gmted, chunks='auto')
gmted_ds_new = gmted_ds.copy(deep=True)

gmted_ds
# Out:
# <xarray.Dataset> Size: 7GB
# Dimensions:    (lat: 21600, lon: 43200)
# Coordinates:
#   * lon        (lon) float64 346kB -180.0 -180.0 -180.0 ... 180.0 180.0 180.0
#   * lat        (lat) float64 173kB -90.0 -89.99 -89.98 ... 89.98 89.99 90.0
# Data variables:
#     landfract  (lat, lon) float32 4GB dask.array<chunksize=(4096, 8192), meta=np.ndarray>
#     htopo      (lat, lon) float32 4GB dask.array<chunksize=(4096, 8192), meta=np.ndarray>
# Attributes:
#     CDI:            Climate Data Interface version 2.0.2 (https://mpimet.mpg....
#     Conventions:    CF-1.6
#     creation_data:  Wed May 18 09:18:44 MDT 2022
#     history:        Wed May 18 09:29:23 2022: cdo merge gmted_bedmachine_stit...
#     CDO:            Climate Data Operators version 2.0.1 (https://mpimet.mpg....

# %% [markdown]
# ### Compute topo and land fraction anomalies & add them to the PI hires variables
# - Note: we wrap the variables in longitude and pad in latitude to deal with extrapolation
# - Note: Using `method="nearest"` in `interp` is prefered, as it better preserves the PI hires info

# %%
def wrap_pad_latlon(ds, lon_name="lon", lat_name="lat"):
    """
    Wrap longitude and pad latitude if ds does not already
    cover [-180, 180] in lon and [-90, 90] in lat.
    """
    out = ds.copy()
    lon = out[lon_name].values
    lat = out[lat_name].values

    # ---- Wrap longitude separately ----
    if lon.min() > -180:
        west_pad = out.isel({lon_name: 0}).copy()
        west_pad = west_pad.assign_coords({lon_name: np.array([lon[0] - 360])})
        out = xr.concat([west_pad, out], dim=lon_name)

    if lon.max() < 180:
        east_pad = out.isel({lon_name: -1}).copy()
        east_pad = east_pad.assign_coords({lon_name: np.array([lon[-1] + 360])})
        out = xr.concat([out, east_pad], dim=lon_name)

    # ---- Pad latitude ----
    if lat.min() > -90:
        south_pad = out.isel({lat_name: 0}).expand_dims({lat_name: [-90]})
        out = xr.concat([south_pad, out], dim=lat_name)

    if lat.max() < 90:
        north_pad = out.isel({lat_name: -1}).expand_dims({lat_name: [90]})
        out = xr.concat([out, north_pad], dim=lat_name)

    return out

# %%
# %%time

dsa_wrap_pad = wrap_pad_latlon(dsa)

lndf_ano_interp = dsa_wrap_pad.lsm.interp(
    lat=gmted_ds.lat, lon=gmted_ds.lon, method="nearest",
)

topo_ano_interp = dsa_wrap_pad.topo.interp(
    lat=gmted_ds.lat, lon=gmted_ds.lon, method="nearest",
)

# Apply landfract anomaly, then clip data into 0 and 1
gmted_ds_new['landfract'] = (gmted_ds['landfract'] + lndf_ano_interp).clip(min=0, max=1)

# Apply topography anomaly:
#   - topo_new = topo + anomaly
#   - Don't decrease too much: if anomaly decreases elevation below 0 over ocean, clip to 0
htopo_new = gmted_ds['htopo'] + topo_ano_interp
gmted_ds_new['htopo'] = xr.where(
    (topo_ano_interp < 0) & (htopo_new < 0) & (gmted_ds_new['landfract'] == 0),
    0, htopo_new)

print(f"Maximum elevation in PI (m): {gmted_ds.htopo.max().values}")
print(f"Minimum elevation in PI (m): {gmted_ds.htopo.min().values}")

print(f"Maximum elevation in Late Pliocene (m): {gmted_ds_new.htopo.max().values}")
print(f"Minimum elevation in Late Pliocene (m): {gmted_ds_new.htopo.min().values}")

print(f"Maximum elevation increase (m): {(gmted_ds_new-gmted_ds).htopo.max().values}")
print(f"Maximum elevation decrease (m): {(gmted_ds_new-gmted_ds).htopo.min().values}")

# Save netcdf file
if os.path.exists(gmted_plio):
    subprocess.run(["rm", "-f", gmted_plio], check=True)

gmted_ds_new.to_netcdf(gmted_plio, mode="w", compute=True)
# Out:
# Maximum elevation in PI (m): 8625.0
# Minimum elevation in PI (m): -430.0
# Maximum elevation in Late Pliocene (m): 8757.0
# Minimum elevation in Late Pliocene (m): -919.61865234375
# Maximum elevation increase (m): 1361.0001220703125
# Maximum elevation decrease (m): -2947.61474609375
# CPU times: user 55.2 s, sys: 7min 22s, total: 8min 17s
# Wall time: 9min 10s

# %% [markdown]
# ### Plot to check results

# %%
fig, axes = plt.subplots(2, 3, figsize=(8, 3),
                         sharex=True, sharey=True,
                         constrained_layout=True)

# Coarsen datasets for quick plotting
thin = 200
prei = gmted_ds.isel(
    lat=slice(None, None, thin), lon=slice(None, None, thin)).compute()
plio = gmted_ds_new.isel(
    lat=slice(None, None, thin), lon=slice(None, None, thin)).compute()
diff = plio - prei

ds_list = [prei, plio, diff]
titles = ['PI', 'Late Pliocene', 'difference']

# Top row: landfrac
for ds, ax, title in zip(ds_list, axes[0, :], titles):
    ds.landfract.plot.pcolormesh(ax=ax)
    ax.set_title(title)

# Bottom row: htopo
for ds, ax, title in zip(ds_list, axes[1, :], titles):
    ds.htopo.plot.pcolormesh(ax=ax)
    ax.set_title(title)

# %%
p1 = plio.htopo.hvplot(
    x='lon', y='lat', width=600, height=400, cmap='RdBu_r')

p2 = plio.landfract.hvplot(
    x='lon', y='lat', width=600, height=400, cmap='RdBu_r')

p1 + p2
# Out:
# :Layout
#    .Image.I  :Image   [lon,lat]   (htopo)
#    .Image.II :Image   [lon,lat]   (landfract)

# %%
p3 = diff.htopo.hvplot(
    x='lon', y='lat', width=600, height=400)

p4 = diff.landfract.hvplot(
    x='lon', y='lat', width=600, height=400)

p3 + p4
# Out:
# :Layout
#    .Image.I  :Image   [lon,lat]   (htopo)
#    .Image.II :Image   [lon,lat]   (landfract)

# %% [markdown]
# ---
# # Step 2: run NCAR Topo: bin_to_cube
# - Input: `gmted_plio`
# - Output: `ncube3000_plio`
# - [Users' Guide](https://github.com/NCAR/Topo/wiki/User's-Guide)
# - Note: we first create the namelist file and then use `qcmd` to run `bin_to_cube`

# %%
# %%time

# Write namelist file first
with open(f"{work_dir}/bin_to_cube.nl", "w") as f:
    f.write(f"""&binparams
raw_latlon_data_file = '{gmted_plio}'
output_file          = '{ncube3000_plio}'
ncube                = 3000
/""")


# Run bin_to_cube with qcmd
cmd = f"""cd {work_dir}; \
qcmd -l walltime=04:00:00 -A p93300324 -l select=1:ncpus=1:mem=200GB \
-- ./bin_to_cube"""

print(cmd)
subprocess.run(cmd, shell=True, check=True)
# Out:
# cd /glade/derecho/scratch/jiangzhu/setup_data/pliomip3; qcmd -l walltime=04:00:00 -A p93300324 -l select=1:ncpus=1:mem=200GB -- ./bin_to_cube
# Waiting on job launch; 6139721.casper-pbs with qsub arguments:
#     qsub  -l select=1:ncpus=1:mem=200GB -A p93300324 -q casper@casper-pbs -l walltime=04:00:00
#
# Warning: no access to tty (Inappropriate ioctl for device).
# Thus no job control in this shell.
# Intermediate cubed-sphere resolution         3000
# Opening:
# /glade/derecho/scratch/jiangzhu/setup_data/pliomip3/gmted2010_modis_bedmachine-
# rawdata-220518_pliomip3_lp_20250830.nc
# lon-lat dimensions:        43200       21600
# min/max of 30sec land fraction    0    1
# read terrain data
# read lon
# read lat
# close file
# done reading data from netCDF file
# compute volume for raw data
# consistency of lat-lon area  2.147739763813661E-010
# mean elevation (raw data)   241.698777626809
# read LANDM_COSLAT from file
# lon-lat dimensions:          360         180
# min/max of landm_coslat  0.000000000000000E+000   1.00000000000000
# read lon
# read lat
# close file
# done reading in LANDM_COSLAT data from netCDF file
# bin lat-lon data to cubed-sphere
# wx out of range   135.515000000000
# CPU times: user 175 ms, sys: 165 ms, total: 340 ms
# Wall time: 1min 20s
# CompletedProcess(args='cd /glade/derecho/scratch/jiangzhu/setup_data/pliomip3; qcmd -l walltime=04:00:00 -A p93300324 -l select=1:ncpus=1:mem=200GB -- ./bin_to_cube', returncode=0)

# %% [markdown]
# ---
# ## Step 3: run NCAR Topo: cube_to_target
# - Input: `ncube3000_plio`
# - Output: `topo_plio`
# - We wrtie a shell script and use `qcmd` to run `cube_to_target`
# - We loop over multiple target grids if needed

# %%
# %%time

script_file = f"{work_dir}/create_pliomip3_lp_topo.csh"

with open(script_file, "w") as f:
    f.write('#!/bin/tcsh\n')
    for key, grid in target_grids.items():
        cmd = [
            f"{work_dir}/cube_to_target",
            f"--intermediate_cs_name {ncube3000_plio}",
            f"--output_data_directory {work_dir}",
            f"--source_data_identifier {source_data_identifier}",
            f"--output_grid {key}",
            f"--grid_descriptor_file {grid['scrip_file']}",
            f"--smoothing_scale {grid['smoothing_scale']}",
            f"--greenlndantarcsgh30_fac {greenlndantarcsgh30_fac}",
            "--jmax_segments 20000",
            "--name_email_of_creator 'Jiang Zhu, jiangzhu@ucar.edu'"
        ]
        
        if grid.get('scrip_file_gll'):
            cmd.append(f"--grid_descriptor_file_gll {grid['scrip_file_gll']}")
    
        f.write(" ".join(cmd) + "\n")

os.chmod(script_file, 0o755)

cmd = f"""qcmd -l walltime=06:00:00 \
  -A p93300324 \
  -l select=1:ncpus=1:mem=200GB \
  -- source {script_file}"""

print(cmd)
subprocess.run(cmd, shell=True, check=True)
# Out:
# qcmd -l walltime=06:00:00   -A p93300324   -l select=1:ncpus=1:mem=200GB   -- source /glade/derecho/scratch/jiangzhu/setup_data/pliomip3/create_pliomip3_lp_topo.csh
# Waiting on job launch; 6139738.casper-pbs with qsub arguments:
#     qsub  -l select=1:ncpus=1:mem=200GB -A p93300324 -q casper@casper-pbs -l walltime=06:00:00
#
# Warning: no access to tty (Inappropriate ioctl for device).
# Thus no job control in this shell.
# No smoothed topo file specified
#
# Namelist settings
# =================
#
# smoothing_scale                 =    200.000000000000
# nwindow_halfwidth               =            0
# ncube_sph_smooth_fine           =            0
# grid_descriptor_fname           =
# /glade/campaign/cesm/cesmdata/inputdata/share/scripgrids/fv1.9x2.5_141008.nc
# intermediate_cubed_sphere_fname =
# /glade/derecho/scratch/jiangzhu/setup_data/pliomip3/gmted2010_modis_bedmachine-
# rawdata-220518_pliomip3_lp_ncube3000_20250830.nc
# output_grid                     = fv1.9x2.5
# luse_prefilter                  =  F
# lfind_ridges                    =  T
# rrfac_max                       =            1
# ldevelopment_diags              =  F
# lridgetiles                     =  F
# smooth_topo_fname               =
# lwrite_rrfac_to_topo_file       =  F
# str_source                      = pliomip3_lp
# interpolate_phis                =  F
# ldistance_weighted_smoother     =  F
# smooth_phis_numcycle            =           -1
# smoothing_over_ocean            =  F
# jmax_segments                   =        20000
# compute_sgh30_from_sgh_fac      =   -1.00000000000000
# greenlndantarcsgh30_fac        =    2.50000000000000
# Opening grid descriptor file :
# /glade/campaign/cesm/cesmdata/inputdata/share/scripgrids/fv1.9x2.5_141008.nc
# File appears to be using SCRIP grid desciptor convention
# dimension of target grid: ntarget=       13824
# maximum number of corners: ncorner=           4
# grid rank: nrank=           2
# target grid is a lat-lon grid
# nlon=         144 nlat=          96
# center of most Northern grid cell is lat=90; similarly for South pole
# rrfac not on file; setting lregional_refinement = .false.
# ... allocating target_rrfac ANYWAY
# Opening intermediate cubed-sphere file :
# /glade/derecho/scratch/jiangzhu/setup_data/pliomip3/gmted2010_modis_bedmachine-
# rawdata-220518_pliomip3_lp_ncube3000_20250830.nc
# cubed-sphere dimension: ncube =         3000
# average grid-spacing at the Equator (degrees):  2.9999999E-02
# cubed-sphere dimension, ncube:         3000
# min/max of landm_coslat -8.912755986093626E-016   1.00000000000000
# min/max of landfrac  0.000000000000000E+000   1.00000000000000
# min/max of terr  -882.665629133937        8399.40885283441
# min/max of sgh30  0.000000000000000E+000   1341.74721698010
# statis           0
# min/max of cube_lon  1.500000000000335E-002   359.985000000000
# min/max of cube_lat  -89.9787842925934        89.9787842925934
# close file
# done reading in data from netCDF file
# ncube_sph_smooth_coarse=         120
# nu_lap                  =   800000000.000000
# Recommended setting for stability
# smooth_phis_numcycle =         7407
# DAcube consistency:  -3.592681707687007E-013
# greenlndantarcsgh30fac2.50
#
#
#
#
#
#
#
#
#
#
#
#
# Writing topo file to
# /glade/derecho/scratch/jiangzhu/setup_data/pliomip3/fv1.9x2.5_pliomip3_lp_nc300
# 0_Laplace0200_noleak_greenlndantarcsgh30fac2.50_20250830.nc
#
#
#
#
#
#
#
#
#
#
#
# jmax_segments set by user =        20000
# anticipated number of overlaps jall_anticipated=   276480000
# Compute overlap weights:
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# #         10      0.07 percent  done    pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# #         20      0.14 percent  done    pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# #         30      0.22 percent  done    pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# #         40      0.29 percent  done    pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# #         50      0.36 percent  done    pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# #         60      0.43 percent  done    pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# #         70      0.51 percent  done    pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# #         80      0.58 percent  done    pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# #         90      0.65 percent  done    pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# #        100      0.72 percent  done    pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# #        110      0.80 percent  done    pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# #        120      0.87 percent  done    pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# #        130      0.94 percent  done    pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# #        140      1.01 percent  done    pole fix
# pole fix
# pole fix
# pole fix
# pole fix
# #      13820     99.97 percent  done
# sum of all weights divided by surface area of sphere  =  4.744848762466497E-007
# actual number of weights    55862940
# anticipated number of weights   276480000
# NO refinement: RRFAC = 1. everywhere
# MINMAX RRFAC RAW MAPPED FIELD   1.00000000000000        1.00000000000000
# SMOOTHING on CUBED SPHERE 10/7/15
# Entering smooth_intermediate_topo_wrap ...
# Will do smoothing of topo on cubed sphere
# Output will go to:
# /glade/derecho/scratch/jiangzhu/setup_data/pliomip3/topo_smooth_pliomip3_lp_nc3
# 000_Co120.nc
# Smoooth height
# #       7407    100.00 percent  done |
# Topo volume BEFORE smoother =    241.698254761605
# Topo volume  AFTER smoother =    215.734082862587
# Difference       =    25.9641718990179
# Smooth Topo volume  AFTER rescaling =    241.698254761606
# Topo volume BEFORE smoother =    241.698254761606
# Topo volume  AFTER smoother =    241.698254761606
# Difference       =   2.171258662546133E-013
# Topo volume  AFTER smoother AND fixer =    241.698254761606
# in find_local_max iopt_ridge_seed=2
# ---> NSW , bloc           84          11
# FACE =            1
# FACE =            2
# FACE =            3
# FACE =            4
# FACE =            5
# FACE =            6
# PANEL =            1
# PANEL =            2
# PANEL =            3
# PANEL =            4
# PANEL =            5
# PANEL =            6
# two sizes of peaks        85901       85901
# SHAPE        85901
# size of peaks in find_ridge        85901
# SHAPE        85901
# ALPHA(1:NCUBE)   -44.9850000000000        44.9850000000000
# GRID scale    3.33584789216564
#   Analyzed Ridges (two-Phase)    85901 out of    85901  NSWx=109 mxdis= 1018.87Phase)    33759 out of    85901  NSWx=113 mxdis= 1228.97Phase)    48709 out of    85901  NSWx= 97 mxdis=   60.156 mxdis= 1643.42Phase)    59934 out of    85901  NSWx=108 mxdis=  391.23Phase)    65009 out of    85901  NSWx=112 mxdis=  243.10Phase)    69809 out of    85901  NSWx= 95 mxdis=  280.96Phase)    73034 out of    85901  NSWx= 91 mxdis=  116.573 mxdis=  151.16Phase)    79834 out of    85901  NSWx=113 mxdis=  700.620 mxdis=  247.997 mxdis=   49.55
# Done with anisotropy analysis
# MIN/MAX area_target  5.962552805823721E-006  1.442890319573612E-003
# MIN/MAX target_area  5.962552805823698E-006  1.442890319573542E-003
# Remapping landfrac
# MIN/MAX before remap:  0.000000000000000E+000   1.00000000000000
# MIN/MAX after remap:  0.000000000000000E+000   1.00000000000001
# Remapping terrain
# MIN/MAX:  -26.4685063251614        5448.79745544877
# MIN/MAX:  -26.4685063251614        5448.79745544877
# Remapping landm_coslat
# MIN/MAX:  0.000000000000000E+000   1.00000000000001
# Remapping SGH30
# scale sgh30 over Greenland and Antarctica (CESM2-style hack) on intermediate cu
# bed-sphere grid
# MIN/MAX:  0.000000000000000E+000   623.150116059906
# max difference between target grid area and remapping software area
# 8.435092901937224E-017
# Elevation data passed min/max consistency check!
#
# mean height (globally) of topography about sea-level for target grid unfiltered
# elevation   241.698254761828        3037.26984617861
# 12.5663706143496
# volume of input cubed-sphere terrain           :   3037.26984617761
# average elevation of input cubed-sphere terrain:   241.698254761563
# average elevation of input cubed-sphere terrain over land:
# 241.698254761547
# compute variance with respect to 3km cubed-sphere data: SGH
# mean height (globally) of topography about sea-level for target grid filtered e
# levation   241.698254761828
# percentage change in mean height between filtered and unfiltered elevations
# 8.983344396454178E-014
# percentage change in mean height between input cubed-sphere and unfiltered elev
# ations -3.296887393499770E-011
# DAcube consistency:  -3.592681707687007E-013
# about to call paintridge2cube
# painting UNIQID
# in paintridge
# Using nsw/2 x nsw/2 ROTATED brush in paintridge
# finished paintridge2cube
# painting MXDIS
# in paintridge
# Using nsw/2 x nsw/2 ROTATED brush in paintridge
# finished paintridge2cube
# painting HWDTH
# in paintridge
# Using nsw/2 x nsw/2 ROTATED brush in paintridge
# finished paintridge2cube
# painting CLNGT
# in paintridge
# Using nsw/2 x nsw/2 ROTATED brush in paintridge
# finished paintridge2cube
# painting ANGLX
# in paintridge
# Using nsw/2 x nsw/2 ROTATED brush in paintridge
# finished paintridge2cube
# painting ANISO
# in paintridge
# Using nsw/2 x nsw/2 ROTATED brush in paintridge
# finished paintridge2cube
# painting MXVRX
# in paintridge
# Using nsw/2 x nsw/2 ROTATED brush in paintridge
# finished paintridge2cube
# painting MXVRY
# in paintridge
# Using nsw/2 x nsw/2 ROTATED brush in paintridge
# finished paintridge2cube
# painting CWGHT
# in paintridge
# Using nsw/2 x nsw/2 ROTATED brush in paintridge
# finished paintridge2cube
# painting FALLQ
# in paintridge
# Using nsw/2 x nsw/2 ROTATED brush in paintridge
# finished paintridge2cube
# painting RISEQ
# in paintridge
# Using nsw/2 x nsw/2 ROTATED brush in paintridge
# finished paintridge2cube
# painting WEDGI
# in paintridge
# Using nsw/2 x nsw/2 ROTATED brush in paintridge
# finished paintridge2cube
# fleshing out BLOCK
# in fleshout_block
# finished panel=           1
# finished panel=           2
# finished panel=           3
# finished panel=           4
# finished panel=           5
# finished panel=           6
# fleshing out PROFI
# finished panel=           1
# finished panel=           2
# finished panel=           3
# finished panel=           4
# finished panel=           5
# finished panel=           6
# fleshing out NODES
# finished panel=           1
# finished panel=           2
# finished panel=           3
# finished panel=           4
# finished panel=           5
# finished panel=           6
# fleshing out WEDGES
# finished panel=           1
# finished panel=           2
# finished panel=           3
# finished panel=           4
# finished panel=           5
# finished panel=           6
# fleshing out NODOS
# finished panel=           1
# finished panel=           2
# finished panel=           3
# finished panel=           4
# finished panel=           5
# finished panel=           6
# fleshing out WEDGO
# finished panel=           1
# finished panel=           2
# finished panel=           3
# finished panel=           4
# finished panel=           5
# finished panel=           6
# Painting IDs on top of WEDGO
# finished panel=           1
# finished panel=           2
# finished panel=           3
# finished panel=           4
# finished panel=           5
# finished panel=           6
# DAcube consistency:  -3.592681707687007E-013
# remap--target
# Min Max ITRGT             2       13824
# !!!!!!!!  ******* maxval terr_target    5725.71974485679
# min/max of landfac_target                :   0.000000000000000E+000
# 1.00000000000001
# min/max of terr source                   :   -882.665629133937
# 8399.40885283441
# min/max of terr_target                   :  -3.174605059184309E-011
# 5725.71974485679
# min/max of landm_coslat_target           :   0.000000000000000E+000
# 1.00000000000001
# min/max of var30_target                  :   0.000000000000000E+000
# 623.150116059906
# min/max of var_target                    :   0.000000000000000E+000
# 1947.25013320982
# Model topo output file
# /glade/derecho/scratch/jiangzhu/setup_data/pliomip3/fv1.9x2.5_pliomip3_lp_nc300
# 0_Laplace0200_noleak_greenlndantarcsgh30fac2.50_20250830.nc
# average pole control volume
# Create NetCDF file for output
# Create dimensions for output
# Create variable for output
# writing terrain data -3.174605059184309E-011   5725.71974485679
# done writing terrain data
# writing landfrac data  0.000000000000000E+000   1.00000000000001
# done writing landfrac data
# writing sgh data  0.000000000000000E+000   1947.25013320982
# done writing sgh data
# writing sgh30 data  0.000000000000000E+000   623.150116059906
# done writing sgh30 data
# writing landm_coslat data  0.000000000000000E+000   1.00000000000001
# done writing sgh30 data
# writing lat data
# done writing lat data
# writing lon data
# done writing lon data
# writing MXDIS  data  0.000000000000000E+000   4071.89632234046
# done writing MXDIS data
# writing RISEQ  data  0.000000000000000E+000   4071.89632234046
# done writing RISEQ data
# writing FALLQ  data  -3485.11799892880       0.000000000000000E+000
# done writing FALLQ data
# writing MXVRX  data  0.000000000000000E+000   2142710.91103314
# done writing MXVRX data
# writing MXVRY  data  0.000000000000000E+000   221755.674459512
# done writing MXVRY data
# writing ANGLL  data  -9000.00000000000        179.999994991044
# done writing ANGLL data
# writing ANGLX  data  -9000.00000000000        168.750000000000
# done writing ANGLX data
# writing ANISO  data  0.000000000000000E+000  0.997347686825588
# done writing ANISO data
# writing ANIXY  data  0.000000000000000E+000  0.997787911454307
# done writing ANIXY data
# writing WGHTS  data  0.000000000000000E+000  4.192511132662364E-005
# done writing WGHTS data
# writing HWDTH  data  0.000000000000000E+000   393.546060052871
# done writing HWDTH data
# writing CLNGT  data  0.000000000000000E+000   554.862553461848
# done writing CLNGT data
# writing CWGHT  data  0.000000000000000E+000  4.192511132662364E-005
# done writing CWGHT data
# writing COUNT  data  0.000000000000000E+000   166.333289585824
# done writing COUNT data
# writing TERR_UF  data  -26.4685063251614        5448.79745544877
# done writing TERR_UF data
# writing SGH_UF  data  0.000000000000000E+000   3960193.30605552
# done writing SGH_UF data
# writing ISOWGT  data  0.000000000000000E+000  0.915172981692710
# done writing ISOWGT data
# writing ISOVAR  data  0.000000000000000E+000   996.022735684409
# done writing ISOVAR data
# writing GBXAR  data  5.962552805823721E-006  1.442890319573612E-003
# done writing GBXAR data
# close file
# CPU times: user 10.2 s, sys: 6.9 s, total: 17.1 s
# Wall time: 59min 6s
# CompletedProcess(args='qcmd -l walltime=06:00:00   -A p93300324   -l select=1:ncpus=1:mem=200GB   -- source /glade/derecho/scratch/jiangzhu/setup_data/pliomip3/create_pliomip3_lp_topo.csh', returncode=0)

# %% [markdown]
# ## Step 4: Use UXarray or Xarray to examine the results

# %%
# --- Variable info ---
# You can add more variables to examine.

vinfo = {
    "PHIS": {"clim": (None, None), "clim_delta": (-10000, 10000)},
    "SGH30": {"clim": (0, 200), "clim_delta": (-50, 50)},
    "SGH": {"clim": (0, 500), "clim_delta": (-100, 100)},
    "ANISO": {"clim": (0, 1), "clim_delta": (-1, 1)},
}
vnames = list(vinfo.keys())

# --- Loop over all grids ---
for grid_name, target_grid in target_grids.items():
    print(f"\n--- Plotting grid: {grid_name} ---")
    print("Pre-industrial file:", target_grid["topo_pre"])
    print("Late Pliocene file:", target_grid["topo_plio"])

    # Open datasets
    if re.search("fv", grid_name):
        ds_topo_pre = xr.open_dataset(target_grid["topo_pre"])
        ds_topo_plio = xr.open_dataset(target_grid["topo_plio"])
    else:
        ds_topo_pre = ux.open_dataset(
            target_grid["scrip_file"], target_grid["topo_pre"])
        ds_topo_plio = ux.open_dataset(
            target_grid["scrip_file"], target_grid["topo_plio"])

    # Loop over variables
    for vname in vnames:
        clim = vinfo[vname]["clim"]
        clim_delta = vinfo[vname]["clim_delta"]

        if re.search("fv", grid_name):  # FV grid → matplotlib
            fields = {
                "Pre-industrial": ds_topo_pre[vname],
                "Pliocene": ds_topo_plio[vname],
                "Δ (Pliocene – Pre-industrial)": ds_topo_plio[vname] - ds_topo_pre[vname],
            }

            fig, axes = plt.subplots(1, len(fields), figsize=(15, 5),
                                     constrained_layout=True)

            for ax, (title, da) in zip(axes, fields.items()):
                # Handle ANISO nrdg selection
                da_plot = da.isel(nrdg=1) if vname == "ANISO" else da

                # Use Δ vs normal clim
                if "Δ" in title:
                    da_plot.plot(
                        ax=ax, vmin=clim_delta[0],
                        vmax=clim_delta[1], cmap="RdBu_r")
                else:
                    if clim[0] is None and clim[1] is None:
                        da_plot.plot(ax=ax, robust=True, cmap="terrain")
                    else:
                        da_plot.plot(
                            ax=ax, vmin=clim[0], vmax=clim[1], cmap="terrain")

                ax.set_title(f"{title} {vname}")

            plt.show()

        else:  # SE / irregular grid → hvplot
            pre = ds_topo_pre[vname].isel(nrdg=1) if vname == "ANISO" else ds_topo_pre[vname]
            delta = (ds_topo_plio[vname] - ds_topo_pre[vname]).isel(nrdg=1) if vname == "ANISO" else (ds_topo_plio[vname] - ds_topo_pre[vname])

            p1 = pre.hvplot.image(width=500, height=300, clim=clim, cmap="terrain")
            p2 = delta.hvplot.image(width=500, height=300, clim=clim_delta, cmap="RdBu_r")
            display(p1 + p2)
# Out:
# --- Plotting grid: fv1.9x2.5 ---
# Pre-industrial file: /glade/campaign/cgd/ppc/jiangzhu/setup_data/cam_topo/pi/fv1.9x2.5_gmted2010_modis_bedmachine_nc3000_Laplace0200_noleak_greenlndantarcsgh30fac2.50_20250818.nc
# Late Pliocene file: /glade/derecho/scratch/jiangzhu/setup_data/pliomip3/fv1.9x2.5_pliomip3_lp_nc3000_Laplace0200_noleak_greenlndantarcsgh30fac2.50_20250830.nc
